# %%
from itertools import accumulate

# %%
arr = [1, 2, 3, 4, 5]
list(accumulate(arr))
# Out:
# [1, 3, 6, 10, 15]

# %%
from collections import deque

starts = deque()
print(not starts)
# Out:
# True
